# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Load .csv dataset
df = pd.read_csv("remote_worker_productivity_1000.csv")

# %% [markdown]
# Data Cleaning/ Preparation -

# %%
# Step 1: Drop Duplicate Rows
df = df.drop_duplicates()

# %%
# Step 2: Check For/ Remove Missing Values
df = df.dropna()

# %%
df.head()
# Out:
#   worker_id location_type industry_sector  age  experience_years  \
# 0     W0001       Village      Healthcare   23                26
# 1     W0002          City      Healthcare   27                27
# 2     W0003       Village          Retail   30                 8
# 3     W0004       Village         Finance   54                19
# 4     W0005          City       Education   46                 1
#
#    average_daily_work_hours  break_frequency_per_day  task_completion_rate  \
# 0                      7.45                        1             66.377024
# 1                      9.82                        3             88.226501
# 2                      7.38                        2             67.004170
# 3                      8.37                        1             66.004424
# 4                      7.51                        4             91.468942
#
#    late_task_ratio  calendar_scheduled_usage  focus_time_minutes  \
# 0         0.254624                 55.496926               106.0
# 1         0.173382                 66.496755               141.0
# 2         0.351835                 41.367064                92.0
# 3         0.347840                 51.086805                94.0
# 4         0.085582                 93.618344               202.0
#
#    tool_usage_frequency  automated_task_count  AI_assisted_planning  \
# 0                    19                    13                     0
# 1                     5                     1                     1
# 2                     4                     4                     0
# 3                    17                     9                     1
# 4                    14                     8                     0
#
#    real_time_feedback_score productivity_label  productivity_score
# 0                        80                Low               32.31
# 1                        83             Medium               41.09
# 2                        81                Low               25.69
# 3                        84                Low               31.98
# 4                        64               High               48.19

# %%
# Step 3: Encode Categorical Variables
label_encoders = {}
for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Step 4: Save Cleaned Data Set
df.to_csv("cleaned_remote_worker_productivity.csv", index = False)

# %%
# View Cleaned Data
print(df.head())
# Out:
#    worker_id  location_type  industry_sector  age  experience_years  \
# 0          0              2                2   23                26
# 1          1              0                2   27                27
# 2          2              2                4   30                 8
# 3          3              2                1   54                19
# 4          4              0                0   46                 1
#
#    average_daily_work_hours  break_frequency_per_day  task_completion_rate  \
# 0                      7.45                        1             66.377024
# 1                      9.82                        3             88.226501
# 2                      7.38                        2             67.004170
# 3                      8.37                        1             66.004424
# 4                      7.51                        4             91.468942
#
#    late_task_ratio  calendar_scheduled_usage  focus_time_minutes  \
# 0         0.254624                 55.496926               106.0
# 1         0.173382                 66.496755               141.0
# 2         0.351835                 41.367064                92.0
# 3         0.347840                 51.086805                94.0
# 4         0.085582                 93.618344               202.0
#
#    tool_usage_frequency  automated_task_count  AI_assisted_planning  \
# 0                    19                    13                     0
# 1                     5                     1                     1
# 2                     4                     4                     0
# 3                    17                     9                     1
# 4                    14                     8                     0
#
#    real_time_feedback_score  productivity_label  productivity_score
# 0                        80                   1               32.31
# 1                        83                   2               41.09
# 2                        81                   1               25.69
# 3                        84                   1               31.98
# 4                        64                   0               48.19
